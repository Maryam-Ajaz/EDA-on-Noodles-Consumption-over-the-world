# %% [markdown]
# # Noodles Consumption data set

# %% [markdown]
# ## Importing dataset using numpy and pandas

# %% [markdown]
# ### numpy and pandas are python libraries used for data manipulation. libraries are tools provided by a language which a programer can use to do things easily

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# here we have imported numpy as np, so we can use numpy with alias np rather than writing full name in our code. same for pandas as pd

# %%
dataset = pd.read_csv("/Users/sett/Downloads/noodles.csv")

# %% [markdown]
# here we use pd because it is used for data handling of dataframes.and we have to give full path of file to import data

# %%
print(dataset)
# Out:
#     Country/Region     2018     2019     2020   2021     2022  Rank CCA3  \
# 0            China  40250.0  41450.0  46360.0  43990  45070.0     1  CHN
# 1        Indonesia  12540.0  12520.0  12640.0  13270  14260.0     4  IDN
# 2            India   6060.0   6730.0   6730.0   7560   7580.0     2  IND
# 3            Japan   5780.0   5630.0   5970.0   5850   5980.0    11  JPN
# 4      Philippines   3980.0   3850.0   4470.0   4440   4290.0    13  PHL
# 5      South Korea   3820.0   3900.0   4130.0   3790   3950.0    29  KOR
# 6         Thailand   3460.0   3570.0   3710.0   3630   3870.0    20  THA
# 7           Brazil   2390.0   2420.0   2720.0   2850   2830.0     7  BRA
# 8          Nigeria   1820.0   1920.0   2460.0   2620   2790.0     6  NGA
# 9           Russia   1850.0   1910.0   2000.0   2100   2200.0     9  RUS
# 10           Nepal   1570.0   1640.0   1540.0   1590   1650.0    49  NPL
# 11        Malaysia   1370.0   1450.0   1570.0   1580   1550.0    45  MYS
# ...

# %% [markdown]
# we can print our complete data use the print function

# %%
dataset.head()
# Out:
#   Country/Region     2018     2019     2020   2021     2022  Rank CCA3  \
# 0          China  40250.0  41450.0  46360.0  43990  45070.0     1  CHN
# 1      Indonesia  12540.0  12520.0  12640.0  13270  14260.0     4  IDN
# 2          India   6060.0   6730.0   6730.0   7560   7580.0     2  IND
# 3          Japan   5780.0   5630.0   5970.0   5850   5980.0    11  JPN
# 4    Philippines   3980.0   3850.0   4470.0   4440   4290.0    13  PHL
#
#   Country/Territory    Capital Continent  2022 Population
# 0             China    Beijing      Asia       1425887337
# 1         Indonesia    Jakarta      Asia        275501339
# 2             India  New Delhi      Asia       1417173173
# 3             Japan      Tokyo      Asia        123951692
# 4       Philippines     Manila      Asia        115559009

# %% [markdown]
# ###### dataset.head() </br> it is used to print only the top rows of a dataset hence called head()

# %%
path = "/Users/sett/Downloads/noodles.csv"
dataset = pd.read_csv(path, header= None)

# %%
print(dataset)
# Out:
#                 0        1        2        3      4        5     6     7   \
# 0   Country/Region   2018.0   2019.0   2020.0   2021   2022.0  Rank  CCA3
# 1            China  40250.0  41450.0  46360.0  43990  45070.0     1   CHN
# 2        Indonesia  12540.0  12520.0  12640.0  13270  14260.0     4   IDN
# 3            India   6060.0   6730.0   6730.0   7560   7580.0     2   IND
# 4            Japan   5780.0   5630.0   5970.0   5850   5980.0    11   JPN
# 5      Philippines   3980.0   3850.0   4470.0   4440   4290.0    13   PHL
# 6      South Korea   3820.0   3900.0   4130.0   3790   3950.0    29   KOR
# 7         Thailand   3460.0   3570.0   3710.0   3630   3870.0    20   THA
# 8           Brazil   2390.0   2420.0   2720.0   2850   2830.0     7   BRA
# 9          Nigeria   1820.0   1920.0   2460.0   2620   2790.0     6   NGA
# 10          Russia   1850.0   1910.0   2000.0   2100   2200.0     9   RUS
# 11           Nepal   1570.0   1640.0   1540.0   1590   1650.0    49   NPL
# ...

# %%
dataset = pd.read_csv(path, names=["mulk","pehla saal", "dusra saal", "teesra saal", "chotha saal", "panchuwa saal", "rutba", "akheer"])

# %%
print(dataset)
# Out:
#                                          mulk  pehla saal dusra saal  \
# Country/Region 2018.0  2019.0  2020.0    2021      2022.0       Rank
# China          40250.0 41450.0 46360.0  43990     45070.0          1
# Indonesia      12540.0 12520.0 12640.0  13270     14260.0          4
# India          6060.0  6730.0  6730.0    7560      7580.0          2
# Japan          5780.0  5630.0  5970.0    5850      5980.0         11
# Philippines    3980.0  3850.0  4470.0    4440      4290.0         13
# South Korea    3820.0  3900.0  4130.0    3790      3950.0         29
# Thailand       3460.0  3570.0  3710.0    3630      3870.0         20
# Brazil         2390.0  2420.0  2720.0    2850      2830.0          7
# Nigeria        1820.0  1920.0  2460.0    2620      2790.0          6
# Russia         1850.0  1910.0  2000.0    2100      2200.0          9
# Nepal          1570.0  1640.0  1540.0    1590      1650.0         49
# Malaysia       1370.0  1450.0  1570.0    1580      1550.0         45
# ...

# %%
#according to column index
dataset = pd.read_csv(path, index_col=7)

# %%
print(dataset)
# Out:
#       Country/Region     2018     2019     2020   2021     2022  Rank  \
# CCA3
# CHN            China  40250.0  41450.0  46360.0  43990  45070.0     1
# IDN        Indonesia  12540.0  12520.0  12640.0  13270  14260.0     4
# IND            India   6060.0   6730.0   6730.0   7560   7580.0     2
# JPN            Japan   5780.0   5630.0   5970.0   5850   5980.0    11
# PHL      Philippines   3980.0   3850.0   4470.0   4440   4290.0    13
# KOR      South Korea   3820.0   3900.0   4130.0   3790   3950.0    29
# THA         Thailand   3460.0   3570.0   3710.0   3630   3870.0    20
# BRA           Brazil   2390.0   2420.0   2720.0   2850   2830.0     7
# NGA          Nigeria   1820.0   1920.0   2460.0   2620   2790.0     6
# RUS           Russia   1850.0   1910.0   2000.0   2100   2200.0     9
# NPL            Nepal   1570.0   1640.0   1540.0   1590   1650.0    49
# MYS         Malaysia   1370.0   1450.0   1570.0   1580   1550.0    45
# ...

# %%
#skip rows
dataset = pd.read_csv(path, skiprows=[0, 2, 3])

# %%
print(dataset)
# Out:
#              China  40250.0  41450.0  46360.0  43990  45070.0    1  CHN  \
# 0            Japan   5780.0   5630.0   5970.0   5850   5980.0   11  JPN
# 1      Philippines   3980.0   3850.0   4470.0   4440   4290.0   13  PHL
# 2      South Korea   3820.0   3900.0   4130.0   3790   3950.0   29  KOR
# 3         Thailand   3460.0   3570.0   3710.0   3630   3870.0   20  THA
# 4           Brazil   2390.0   2420.0   2720.0   2850   2830.0    7  BRA
# 5          Nigeria   1820.0   1920.0   2460.0   2620   2790.0    6  NGA
# 6           Russia   1850.0   1910.0   2000.0   2100   2200.0    9  RUS
# 7            Nepal   1570.0   1640.0   1540.0   1590   1650.0   49  NPL
# 8         Malaysia   1370.0   1450.0   1570.0   1580   1550.0   45  MYS
# 9           Mexico   1120.0   1170.0   1160.0   1360   1510.0   10  MEX
# 10          Taiwan    830.0    830.0    870.0    900    880.0   57  TWN
# 11    Saudi Arabia    550.0    560.0    830.0    850    870.0   41  SAU
# ...

# %%
pd.isna(dataset)
# Out:
#     China  40250.0  41450.0  46360.0  43990  45070.0      1    CHN  China.1  \
# 0   False    False    False    False  False    False  False  False    False
# 1   False    False    False    False  False    False  False  False    False
# 2   False    False    False    False  False    False  False  False    False
# 3   False    False    False    False  False    False  False  False    False
# 4   False    False    False    False  False    False  False  False    False
# 5   False    False    False    False  False    False  False  False    False
# 6   False    False    False    False  False    False  False  False    False
# 7   False    False    False    False  False    False  False  False    False
# 8   False    False    False    False  False    False  False  False    False
# 9   False    False    False    False  False    False  False  False    False
# 10  False    False    False    False  False    False  False  False    False
# ...

# %%
#read limited number of rows
dataset = pd.read_csv(path, nrows=5)

# %%
print(dataset)
# Out:
#   Country/Region     2018     2019     2020   2021     2022  Rank CCA3  \
# 0          China  40250.0  41450.0  46360.0  43990  45070.0     1  CHN
# 1      Indonesia  12540.0  12520.0  12640.0  13270  14260.0     4  IDN
# 2          India   6060.0   6730.0   6730.0   7560   7580.0     2  IND
# 3          Japan   5780.0   5630.0   5970.0   5850   5980.0    11  JPN
# 4    Philippines   3980.0   3850.0   4470.0   4440   4290.0    13  PHL
#
#   Country/Territory    Capital Continent  2022 Population
# 0             China    Beijing      Asia       1425887337
# 1         Indonesia    Jakarta      Asia        275501339
# 2             India  New Delhi      Asia       1417173173
# 3             Japan      Tokyo      Asia        123951692
# 4       Philippines     Manila      Asia        115559009

# %%
dataset.to_csv("/Users/sett/Desktop/somedata.csv")

# %%
#reading new dataset 
newpath = "/Users/sett/Desktop/somedata.csv"
dataset2 = pd.read_csv(newpath)

# %%
dataset = pd.read_csv(path)

# %%
print(dataset)
print("========================================================")
print(dataset2)
# Out:
#     Country/Region     2018     2019     2020   2021     2022  Rank CCA3  \
# 0            China  40250.0  41450.0  46360.0  43990  45070.0     1  CHN
# 1        Indonesia  12540.0  12520.0  12640.0  13270  14260.0     4  IDN
# 2            India   6060.0   6730.0   6730.0   7560   7580.0     2  IND
# 3            Japan   5780.0   5630.0   5970.0   5850   5980.0    11  JPN
# 4      Philippines   3980.0   3850.0   4470.0   4440   4290.0    13  PHL
# 5      South Korea   3820.0   3900.0   4130.0   3790   3950.0    29  KOR
# 6         Thailand   3460.0   3570.0   3710.0   3630   3870.0    20  THA
# 7           Brazil   2390.0   2420.0   2720.0   2850   2830.0     7  BRA
# 8          Nigeria   1820.0   1920.0   2460.0   2620   2790.0     6  NGA
# 9           Russia   1850.0   1910.0   2000.0   2100   2200.0     9  RUS
# 10           Nepal   1570.0   1640.0   1540.0   1590   1650.0    49  NPL
# 11        Malaysia   1370.0   1450.0   1570.0   1580   1550.0    45  MYS
# ...
